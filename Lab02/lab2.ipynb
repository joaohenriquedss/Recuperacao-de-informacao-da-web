# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import re


# %matplotlib inline

arquivo = pd.read_csv('results.csv')

texto = arquivo['text']

def filtro_de_palavras(text):
  return re.sub(r'(\W+|\d+|\b\w{0,3}\b)', ' ', text.lower())
texto = texto.apply(filtro_de_palavras)

arquivo.head()
# Out:
#                                                title            date  \
# 0  De cada 4 venezuelanos, 1 precisa de ajuda hum...  04.04.19 21:00
# 1  Publicação contra o Hamas é página virada, diz...  04.04.19 14:39
# 2                          Maduro despacha do bunker  04.04.19 18:00
# 3     Ex-estrategista de Trump volta a atacar Mourão  04.04.19 18:40
# 4  Ditadura da Venezuela prende 47 por pedirem lu...  04.04.19 19:00
#
#                                                 text    auhor category  \
# 0  Um documento de 45 páginas vazado da ONU calcu...  Ernesto    Mundo
# 1  De volta de Israel, onde fez parte da comitiva...  Heloisa    Mundo
# 2  O ditador Nicolás Maduro não despacha do Palác...     Nina    Mundo
# 3  Steve Bannon, ex-estrategista de Donald Trump,...     Cino    Mundo
# 4  Entre 29 de março e 1º de abril, 47 pessoas fo...   GILMAR    Mundo
#
#                                                  url
# 0  https://www.oantagonista.com/mundo/de-cada-4-v...
# 1  https://www.oantagonista.com/mundo/publicacao-...
# 2  https://www.oantagonista.com/mundo/maduro-desp...
# 3  https://www.oantagonista.com/mundo/ex-estrateg...
# 4  https://www.oantagonista.com/mundo/ditadura-da...

# %%
formatando_texto = texto.str.cat(sep=' ')
palavras = pd.DataFrame([text for text in formatando_texto.split(' ') if len(text) > 0], columns=['palavra'])
palavras.describe()
# Out:
#        palavra
# count     1751
# unique     623
# top       para
# freq        37

# %%
frequencia = palavras['palavra'].value_counts()
tamanho_do_vocabulario =  len(palavras.palavra.unique())

# %%
tabela = {}
tabela['Total de documentos'] = len(arquivo)
tabela['Total de ocorrências de palavras'] = len(palavras)
tabela['Tamanho do Vocabulário'] = tamanho_do_vocabulario
tabela['Palavras que ocorrem> 1000 '] = len(frequencia[frequencia > 1000])
tabela['Palavras que ocorrem uma vez'] = len(frequencia[frequencia == 1])
tabela_estatistica = pd.DataFrame(tabela, index=[1])
tabela_estatistica
# Out:
#    Total de documentos  Total de ocorrências de palavras  \
# 1                  121                              1751
#
#    Tamanho do Vocabulário  Palavras que ocorrem> 1000   \
# 1                     623                            0
#
#    Palavras que ocorrem uma vez
# 1                           256

# %%
rank = np.arange(0, tamanho_do_vocabulario) + 1 
frequencia_relativa = palavras['palavra'].value_counts(normalize = 'true')
print("Top-50 palavras mais frequentes em 100 noticias no site oantagonista")

frequencia_top_50 = {
    'Frequencia': frequencia,
    'Rank' : rank,
    'P(%)' : frequencia_relativa * 100,
    'P*Rank' : (frequencia_relativa * 100) * rank
}

frequencia_top_50 = pd.DataFrame(frequencia_top_50)
frequencia_top_50.head(50)
# Out:
# Top-50 palavras mais frequentes em 100 noticias no site oantagonista
#             Frequencia  Rank      P(%)     P*Rank
# para                37     1  2.113078   2.113078
# bolsonaro           29     2  1.656196   3.312393
# jair                22     3  1.256425   3.769275
# hoje                18     4  1.027984   4.111936
# disse               15     5  0.856653   4.283267
# justiça             15     6  0.856653   5.139920
# mais                15     7  0.856653   5.996573
# folha               14     8  0.799543   6.396345
# contra              13     9  0.742433   6.681896
# grupo               11    10  0.628212   6.282125
# registra            11    11  0.628212   6.910337
# está                11    12  0.628212   7.538549
# evento              10    13  0.571102   7.424329
# pelo                10    14  0.571102   7.995431
# joão                10    15  0.571102   8.566533
# doria               10    16  0.571102   9.137636
# milhões             10    17  0.571102   9.708738
# projeto              9    18  0.513992   9.251856
# brasil               9    19  0.513992   9.765848
# nicolás              9    20  0.513992  10.279840
# pela                 9    21  0.513992  10.793832
# depois               9    22  0.513992  11.307824
# maduro               9    23  0.513992  11.821816
# segundo              9    24  0.513992  12.335808
# caixa                9    25  0.513992  12.849800
# federal              8    26  0.456882  11.878926
# flávio               7    27  0.399772  10.793832
# pessoas              7    28  0.399772  11.193604
# tribunal             7    29  0.399772  11.593375
# relata               7    30  0.399772  11.993147
# terrorista           7    31  0.399772  12.392918
# muito                7    32  0.399772  12.792690
# neste                7    33  0.399772  13.192461
# como                 7    34  0.399772  13.592233
# mesmo                7    35  0.399772  13.992005
# seja                 7    36  0.399772  14.391776
# porque               7    37  0.399772  14.791548
# globo                6    38  0.342661  13.021131
# presidente           6    39  0.342661  13.363792
# campos               6    40  0.342661  13.706453
# brasília             6    41  0.342661  14.049115
# melhor               6    42  0.342661  14.391776
# lide                 6    43  0.342661  14.734437
# três                 6    44  0.342661  15.077099
# jordão               6    45  0.342661  15.419760
# palácio              6    46  0.342661  15.762421
# união                6    47  0.342661  16.105083
# ditadura             6    48  0.342661  16.447744
# informa              6    49  0.342661  16.790405
# pedra                6    50  0.342661  17.133067

# %%
fig,ax = plt.subplots()

ax.plot(rank, frequencia)
plt.title('Grafico')

plt.xlabel('Rank')
plt.ylabel('Frequencia')
plt.show()

# %% [markdown]
# Escala logarítmica

# %%
import seaborn as sns
f, ax = plt_pyp.subplots()
ax.set(xscale="log", yscale="log")

sns.regplot(x="Frequencia", y="Rank", data=frequencia_top_50)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

bigramas = list(nltk.bigrams(list(palavras['palavra'].values)))


bigramas = pd.DataFrame({
    'Bigrama' : list(nltk.FreqDist(bigramas).keys()),
    'Frequencia' : list(nltk.FreqDist(bigramas).values()),
})

bigramas['Rank'] = bigramas['Frequencia'].rank(ascending=True, method='first')
bigramas = bigramas.sort_values(by='Frequencia')
bigramas.tail()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                  Bigrama  Frequencia   Rank
# 20   (flávio, bolsonaro)           7  878.0
# 343      (mesmo, porque)           7  879.0
# 34     (nicolás, maduro)           9  880.0
# 228        (joão, doria)          10  881.0
# 66     (jair, bolsonaro)          19  882.0

# %%
f, ax = plt_pyp.subplots()
ax.set(xscale="log", yscale="log")

sns.regplot(x="Frequencia", y="Rank", data=bigramas)

# %%
def p(freq):
  return freq / tamanho_do_vocabulario

grupo_freq = frequencia_top_50.groupby('Frequencia')['Rank']
num_palavras = grupo_freq.count()
prop_atual = num_palavras.apply(p)


propocao_p = {
    'Proporcaoo Atual': prop_atual,
    'Numero de Palavras': num_palavras,
}

propocao_p = pd.DataFrame(propocao_p)
propocao_p.head()
# Out:
#             Proporcaoo Atual  Numero de Palavras
# Frequencia
# 1                   0.410915                 256
# 2                   0.105939                  66
# 3                   0.245586                 153
# 4                   0.133226                  83
# 5                   0.022472                  14
